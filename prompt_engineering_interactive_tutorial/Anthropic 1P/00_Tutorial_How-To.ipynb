# %% [markdown]
# # 教程使用指南
#
# 本教程**需要 API 密钥**才能进行交互。如果你没有 API 密钥，可以通过 [Anthropic Console](https://console.anthropic.com/) 注册获取，或者查看我们的[静态教程参考答案](https://docs.google.com/spreadsheets/u/0/d/1jIxjzUWG-6xBVIa2ay6yDpLyeuOh_hR_ZB75a47KX_E/edit)。

# %% [markdown]
# ## 如何开始
#
# 1. 将本仓库克隆到本地机器。
#
# 2. 运行以下命令安装所需依赖：

# %%
# %pip install anthropic

# %% [markdown]
# 3. 设置你的 API 密钥和模型名称。将 `"your_api_key_here"` 替换为你的实际 Anthropic API 密钥。

# %%
API_KEY = "your_api_key_here"
MODEL_NAME = "claude-3-haiku-20240307"

# Stores the API_KEY & MODEL_NAME variables for use across notebooks within the IPython store
# %store API_KEY
# %store MODEL_NAME

# %% [markdown]
# 4. 按照顺序运行笔记本单元格，并遵循所提供的说明。

# %% [markdown]
# ---
#
# ## 使用说明与技巧 💡
#
# - 本课程使用温度为 0 的 Claude 3 Haiku。我们将在课程后面详细讨论温度。现在你只需要了解，这些设置会产生更确定性的结果。本课程中的所有提示工程技巧也适用于上一代遗留 Claude 模型，如 Claude 2 和 Claude Instant 1.2。
#
# - 你可以使用 `Shift + Enter` 来执行当前单元格并移动到下一个单元格。
#
# - 当你到达教程页面底部时，导航到文件夹中的下一个编号文件，或者如果已经完成该章节文件的内容，则进入下一个编号文件夹。
#
# ### Anthropic SDK 与 Messages API
# 在本教程中，我们将使用 [Anthropic Python SDK](https://docs.anthropic.com/claude/reference/client-sdks) 和 [Messages API](https://docs.anthropic.com/claude/reference/messages_post)。
#
# 下面是一个在本教程中运行提示词的示例。首先，我们创建 `get_completion`，这是一个辅助函数，用于向 Claude 发送提示词并返回 Claude 生成的响应。现在运行该单元格。

# %%
import anthropic

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# 现在我们将编写一个示例提示词给 Claude，并通过运行 `get_completion` 辅助函数来打印 Claude 的输出。运行下面的单元格会在其下方打印出 Claude 的响应。
#
# 你可以随意修改提示词字符串，以引导 Claude 产生不同的回应。

# %%
# Prompt
prompt = "Hello, Claude!"

# Get Claude's response
print(get_completion(prompt))

# %% [markdown]
# 之前定义的 `API_KEY` 和 `MODEL_NAME` 变量将在整个教程中使用。请确保按从上到下的顺序运行每个教程页面的单元格。
